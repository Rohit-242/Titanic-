# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy as sp
import statsmodels as sm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('https://gist.githubusercontent.com/fyyying/4aa5b471860321d7b47fd881898162b7/raw/6907bb3a38bfbb6fccf3a8b1edfb90e39714d14f/titanic_dataset.csv',index_col=0)

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
df = data.copy()

# %%
sns.countplot(df['Survived']);
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df['Sex']);
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.crosstab(index=df['Sex'],columns=df['Pclass'])
# Out:
# Pclass    1    2    3
# Sex
# female   94   76  144
# male    122  108  347

# %%
df[(df['Pclass']==3)&(df['Fare']<=20)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 3                   1       3
# 5                   0       3
# 6                   0       3
# 9                   1       3
# ...               ...     ...
# 879                 0       3
# 882                 0       3
# 883                 0       3
# 885                 0       3
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# ...                                                        ...     ...   ...
# ...

# %%
df[df['Pclass']==1]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 12                  1       1
# 24                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 12                                    Bonnell, Miss. Elizabeth  female  58.0
# 24                                Sloper, Mr. William Thompson    male  28.0
# ...                                                        ...     ...   ...
# ...

# %%
df[df['Fare']==df['Fare'].max()]
# Out:
#              Survived  Pclass                                Name     Sex  \
# PassengerId
# 259                 1       1                    Ward, Miss. Anna  female
# 680                 1       1  Cardeza, Mr. Thomas Drake Martinez    male
# 738                 1       1              Lesurer, Mr. Gustave J    male
#
#               Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# PassengerId
# 259          35.0      0      0  PC 17755  512.3292          NaN        C
# 680          36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 738          35.0      0      0  PC 17755  512.3292         B101        C

# %%
df[df['Fare']==df['Fare'].min()]
# Out:
#              Survived  Pclass                              Name   Sex   Age  \
# PassengerId
# 180                 0       3               Leonard, Mr. Lionel  male  36.0
# 264                 0       1             Harrison, Mr. William  male  40.0
# 272                 1       3      Tornquist, Mr. William Henry  male  25.0
# 278                 0       2       Parkes, Mr. Francis "Frank"  male   NaN
# 303                 0       3   Johnson, Mr. William Cahoone Jr  male  19.0
# 414                 0       2    Cunningham, Mr. Alfred Fleming  male   NaN
# 467                 0       2             Campbell, Mr. William  male   NaN
# 482                 0       2  Frost, Mr. Anthony Wood "Archie"  male   NaN
# 598                 0       3               Johnson, Mr. Alfred  male  49.0
# 634                 0       1     Parr, Mr. William Henry Marsh  male   NaN
# 675                 0       2        Watson, Mr. Ennis Hastings  male   NaN
# ...

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df[df['Age']==df['Age'].max()]
# Out:
#              Survived  Pclass                                  Name   Sex  \
# PassengerId
# 631                 1       1  Barkworth, Mr. Algernon Henry Wilson  male
#
#               Age  SibSp  Parch Ticket  Fare Cabin Embarked
# PassengerId
# 631          80.0      0      0  27042  30.0   A23        S

# %%
df.corr()
# Out:
#           Survived    Pclass       Age     SibSp     Parch      Fare
# Survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# Pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# Age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# SibSp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# Parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# Fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
sns.heatmap(df.corr(),annot=True);

# %%
sns.boxplot(df['Fare']);
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.kdeplot(df['Fare'])
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
df.shape
# Out:
# (891, 11)

# %%
num_data = df.select_dtypes(include=np.number)

# %%
num_data.head()
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 1                   0       3  22.0      1      0   7.2500
# 2                   1       1  38.0      1      0  71.2833
# 3                   1       3  26.0      0      0   7.9250
# 4                   1       1  35.0      1      0  53.1000
# 5                   0       3  35.0      0      0   8.0500

# %%
num_data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
for i in num_data.columns:
    q1 = num_data[i].quantile(.1)
    q3 = num_data[i].quantile(.9)
    iqr = q3-q1
    ub = q3+3*iqr
    lb = q1-3*iqr
    data_out = num_data[(num_data[i]>lb)&(num_data[i]<ub)]
    percent = len(data_out)/len(num_data)*100
    print('The percentage of non-outlier data in',i,percent)
# Out:
# The percentage of outlier data in Survived 100.0
# The percentage of outlier data in Pclass 100.0
# The percentage of outlier data in Age 80.13468013468014
# The percentage of outlier data in SibSp 96.63299663299664
# The percentage of outlier data in Parch 100.0
# The percentage of outlier data in Fare 99.66329966329967

# %%
data_out
# Out:
#              Survived  Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 1                   0       3  22.0      1      0   7.2500
# 2                   1       1  38.0      1      0  71.2833
# 3                   1       3  26.0      0      0   7.9250
# 4                   1       1  35.0      1      0  53.1000
# 5                   0       3  35.0      0      0   8.0500
# ...               ...     ...   ...    ...    ...      ...
# 887                 0       2  27.0      0      0  13.0000
# 888                 1       1  19.0      0      0  30.0000
# 889                 0       3   NaN      1      2  23.4500
# 890                 1       1  26.0      0      0  30.0000
# 891                 0       3  32.0      0      0   7.7500
#
# [888 rows x 6 columns]

# %%
sns.boxplot(data_out['Fare']);
# Out:
# D:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(data_out);

# %%
cat = df.select_dtypes(exclude=np.number)

# %%
data = pd.concat([data_out,cat],axis=1)

# %%
data.drop(['Name','Cabin','Ticket'],axis=1,inplace=True)

# %%
data.to_csv('Titanic-data.csv')
